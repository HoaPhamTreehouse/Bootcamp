# %%
from OHLC_CandlestickChart import OHLC_Candlestick_chart

# %%
pair = "BTCUSDT"
interval = "1h"
limit = 1000

# %%
param = f"?symbol={pair}&interval={interval}&limit={limit}"
data = OHLC_Candlestick_chart(pair, interval, limit)

# %%
data.write_html("image.html")

# %%
import pickle
pickle.dumps(data)
# Out:
# b'\x80\x04\x95\r\x00\x01\x00\x00\x00\x00\x00\x8c\x19plotly.graph_objs._figure\x94\x8c\x06Figure\x94\x93\x94}\x94(\x8c\x04data\x94]\x94(}\x94(\x8c\x05close\x94\x8c\x15numpy.core.multiarray\x94\x8c\x0c_reconstruct\x94\x93\x94\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94K\x00\x85\x94C\x01b\x94\x87\x94R\x94(K\x01M\xe8\x03\x85\x94h\x0b\x8c\x05dtype\x94\x93\x94\x8c\x02f8\x94\x89\x88\x87\x94R\x94(K\x03\x8c\x01<\x94NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89B@\x1f\x00\x00\x1f\x85\xebQ\xb8"\xd7@\\\x8f\xc2\xf5\xc8\xce\xd6@\x85\xebQ\xb8N\xdf\xd6@\x85\xebQ\xb8n\x00\xd7@\x8f\xc2\xf5(\xfc\xfa\xd6@H\xe1z\x14>\x13\xd7@\xcd\xcc\xcc\xcc\xbc\r\xd7@\x00\x00\x00\x00`\xf6\xd6@H\xe1z\x14\x9e\xf1\xd6@\xf6(\\\x8f\x92\xf1\xd6@\xecQ\xb8\x1e\x15\xfc\xd6@\n\xd7\xa3pm\xe5\xd6@\xa4p=\nw\xe3\xd6@\xe1z\x14\xae\xf7\xd7\xd6@\x14\xaeG\xe1\xea\xe4\xd6@\\\x8f\xc2\xf5\x18\xda\xd6@\\\x8f\xc2\xf5\xe8\xd3\xd6@\x85\xebQ\xb8\xae\xdd\xd6@\xf6(\\\x8f\xe2\xce\xd6@\xcd\xcc\xcc\xcc<\xc3\xd6@\n\xd7\xa3p]\xc2\xd6@\xa4p=\nG\xd
# ...
